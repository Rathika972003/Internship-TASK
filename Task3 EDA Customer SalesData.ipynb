# %%
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/rathi/Downloads/customer_sales_data.csv")

# %%
df
# Out:
#     Customer_ID  Age      Gender     Location Product_Category  \
# 0      CUST0001   56      Female     New York         Clothing
# 1      CUST0002   69  Non-Binary      Phoenix             Toys
# 2      CUST0003   46        Male      Houston  Home Appliances
# 3      CUST0004   32      Female  Los Angeles             Toys
# 4      CUST0005   60        Male     New York  Home Appliances
# ..          ...  ...         ...          ...              ...
# 195    CUST0196   69      Female     New York         Clothing
# 196    CUST0197   30  Non-Binary      Phoenix  Home Appliances
# 197    CUST0198   58      Female      Phoenix      Electronics
# 198    CUST0199   20  Non-Binary  Los Angeles             Toys
# 199    CUST0200   56      Female  Los Angeles             Toys
#
#      Purchase_Amount Purchase_Date  Customer_Satisfaction
# 0             155.60    2024-02-16                      2
# 1             927.32    2024-03-08                      1
# ...

# %%
df.head(5)
# Out:
#   Customer_ID  Age      Gender     Location Product_Category  Purchase_Amount  \
# 0    CUST0001   56      Female     New York         Clothing           155.60
# 1    CUST0002   69  Non-Binary      Phoenix             Toys           927.32
# 2    CUST0003   46        Male      Houston  Home Appliances           497.20
# 3    CUST0004   32      Female  Los Angeles             Toys           265.66
# 4    CUST0005   60        Male     New York  Home Appliances           464.54
#
#   Purchase_Date  Customer_Satisfaction
# 0    2024-02-16                      2
# 1    2024-03-08                      1
# 2    2024-03-16                      5
# 3    2024-05-09                      1
# 4    2024-04-04                      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            200 non-null    object
#  1   Age                    200 non-null    int64
#  2   Gender                 200 non-null    object
#  3   Location               200 non-null    object
#  4   Product_Category       200 non-null    object
#  5   Purchase_Amount        200 non-null    float64
#  6   Purchase_Date          200 non-null    object
#  7   Customer_Satisfaction  200 non-null    int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 12.6+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Gender                   0
# Location                 0
# Product_Category         0
# Purchase_Amount          0
# Purchase_Date            0
# Customer_Satisfaction    0
# dtype: int64

# %%
df.describe()
# Out:
#              Age  Purchase_Amount  Customer_Satisfaction
# count  200.00000       200.000000             200.000000
# mean    43.42500       462.697300               2.970000
# std     14.94191       277.532345               1.448999
# min     18.00000        29.870000               1.000000
# 25%     31.00000       199.070000               2.000000
# 50%     43.50000       434.260000               3.000000
# 75%     56.00000       686.890000               4.000000
# max     69.00000       990.060000               5.000000

# %%
 df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(8, 8))  # Set the figure size for the pie chart
location_counts = df['Location'].value_counts()  # Count occurrences for each location
plt.pie(location_counts, labels=location_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))  # Create the pie chart
plt.title('Distribution of customer Locations')  # Add a title
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size for the box plot
sns.boxplot(x='Product_Category', y='Purchase_Amount', data=df, palette='pastel')  # Create the box plot
plt.title('Product Category vs. Purchase Amount')  # Add a title
plt.xlabel('Product Category')  # Label the x-axis
plt.ylabel('Purchase Amount')  # Label the y-axis
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
plt.show()
# Out:
# C:\Users\rathi\AppData\Local\Temp\ipykernel_21040\210090350.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Product_Category', y='Purchase_Amount', data=df, palette='pastel')  # Create the box plot

# %%
numeric_df = df.select_dtypes(include=['number'])

# Check correlation matrix
numeric_df.corr()
# Out:
#                             Age  Purchase_Amount  Customer_Satisfaction
# Age                    1.000000         0.063362              -0.129616
# Purchase_Amount        0.063362         1.000000              -0.097493
# Customer_Satisfaction -0.129616        -0.097493               1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap')
plt.show()
